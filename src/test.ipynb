# %%
import pandas as pd

# %%
df = pd.read_csv('../data/data_full_processed.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               125 non-null    object
#  1   link                125 non-null    object
#  2   abstract            125 non-null    object
#  3   processed_abstract  125 non-null    object
# dtypes: object(4)
# memory usage: 4.0+ KB

# %%
# print abstract column and processed_abstract column for the first 5 rows. show full text
pd.set_option('display.max_colwidth', None)
print(df[['abstract', 'processed_abstract']].head(1))
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...
