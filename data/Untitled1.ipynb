# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
data = pd.read_csv("data_with_clusters_bert_08.csv")
data.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0  Investigating the Energy Production through Su...
# 1           1  Sustainability Is Not Enough: Towards AI Suppo...
# 2           2                   AI Legitimacy for Sustainability
# 3           3  Keynote: AI for Scientific Discovery and a Sus...
# 4           4  Explainable AI for predicting daily household ...
#
#                                             abstract  \
# 0  Artificial Intelligence (AI) has the potential...
# 1  Sustainability, to describe it in simpler word...
# 2  Sustainability is a vast subject involving var...
# 3  Artificial Intelligence (AI) is a rapidly adva...
# 4  In the recent era, for most sustainable smart ...
#
#                                   processed_abstract  clusters
# 0  potential predict generation solar wind source...         5
# 1  describe simpler words bad limits destruction ...         4
# 2  vast subject involving research possibilities ...         7
# 3  advancing reasoning reach new milestones world...         1
# 4  point consideration urbanization carried expon...         1

# %%
data.loc[data['clusters'] == 0].shape
# Out:
# (33, 5)

# %%
# Initialize TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Create a dictionary to store important words for each cluster
important_words_per_cluster = {}

# Iterate through each cluster
for cluster_idx in data['clusters'].unique():
    cluster_data = data[data['clusters'] == cluster_idx]['processed_abstract']
    
    # Fit and transform the TF-IDF matrix for the current cluster
    tfidf_matrix = tfidf_vectorizer.fit_transform(cluster_data)
    
    # Get feature names (words)
    feature_names = tfidf_vectorizer.get_feature_names_out()
    
    # Calculate the sum TF-IDF scores for each word in the cluster
    sum_tfidf_scores = tfidf_matrix.sum(axis=0)
    
    # Convert the sum TF-IDF scores to a flat list
    sum_tfidf_scores_list = sum_tfidf_scores.A1
    
    # Sort indices by sum TF-IDF scores (higher scores first)
    sorted_indices = sorted(range(len(sum_tfidf_scores_list)), key=lambda i: sum_tfidf_scores_list[i], reverse=True)
    
    # Extract the top N important words (e.g., top 10 words)
    top_n_words = [feature_names[i] for i in sorted_indices[:4]]
    
    important_words_per_cluster[cluster_idx] = top_n_words

# Print the important words for each cluster
for cluster_idx, words in important_words_per_cluster.items():
    print(f"Cluster {cluster_idx}: {', '.join(words)}")
# Out:
# Cluster 4: power, smart, solar, consumption
# Cluster 0: data, learning, development, load
# Cluster 1: systems, system, smart, learning
# Cluster 3: smart, power, data, system
# Cluster 7: iot, data, water, system
# Cluster 5: smart, data, grid, consumption
# Cluster -1: control, smart, wind, new
# Cluster 6: power, data, smart, learning
# Cluster 8: iot, consumption, learning, design
# Cluster 2: solar, system, power, smart

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
# Group by cluster
grouped = data.groupby('clusters')

# Initialize CountVectorizer
vectorizer = CountVectorizer(stop_words=ENGLISH_STOP_WORDS)

for cluster, group in grouped:
    texts = group['processed_abstract']
    # Fit and transform the texts using CountVectorizer
    X = vectorizer.fit_transform(texts)
    
    # Get feature names (words)
    feature_names = vectorizer.get_feature_names_out()
    
    # Sum the occurrences of each word
    word_counts = X.sum(axis=0)
    
    # Create a DataFrame to hold word frequencies
    word_freq_df = pd.DataFrame({'word': feature_names, 'frequency': word_counts.tolist()[0]})
    
    # Sort by frequency in descending order and get top 10 words
    top_words = word_freq_df.sort_values(by='frequency', ascending=False).head(30)
    
    print(f"Cluster {cluster}:")
    print(top_words)
    print("\n")
# Out:
# Cluster -1:
#              word  frequency
# 71           data         25
# 45         cities         13
# 276         smart         13
# 319          wind         12
# 62        control          8
# 34            big          8
# 316        values          7
# 154           iot          7
# 20   architecture          7
# 221    prediction          6
# 86    electricity          6
# 219         power          6
# 27          axies          6
# 228          prim          5
# 133         human          5
# 99        extreme          5
# 204        panels          5
# 41     challenges          4
# 134        impact          4
# 225       present          4
# 32       benefits          4
# 166         local          4
# 297    techniques          4
# 172   measurement          4
# 88            end          4
# 56     congestion          4
# 108   forecasting          4
# 25      automated          4
# 183        models          4
# 84           edge          4
#
#
# Cluster 0:
#              word  frequency
# 358      learning         21
# 346           iot         20
# 123          data         20
# 105   consumption         17
# 506         power         16
# 607         smart         15
# 719          wind         13
# 720      wireless         12
# 122         cyber         11
# 141        design         11
# 335      internet         10
# 107       control         10
# 145   development         10
# 436       natural         10
# 287          home          9
# 406       methods          9
# 489   performance          8
# 646      tactical          8
# 131          deep          8
# 424        models          8
# 462    operations          8
# 429    monitoring          7
# 442      networks          7
# 494  photovoltaic          7
# 517       problem          7
# 28   applications          7
# 569     resources          7
# 656        things          7
# 588    scheduling          6
# 518      problems          6
#
#
# Cluster 1:
#              word  frequency
# 696         smart         32
# 398           iot         32
# 112     computing         19
# 483           new         17
# 556         power         17
# 218          edge         16
# 59       building         15
# 725      strategy         13
# 422      learning         12
# 393      internet         11
# 329         green         11
# 752    technology         11
# 129   consumption         10
# 751  technologies         10
# 179        design         10
# 166          deep         10
# 184       devices          9
# 157          data          9
# 561    prediction          9
# 744       systems          8
# 466         model          8
# 452           mec          8
# 446     materials          8
# 350         human          8
# 388   intelligent          8
# 500    offloading          8
# 144     countries          8
# 317           gcc          8
# 582      proposed          7
# 142          cost          7
#
#
# Cluster 2:
#               word  frequency
# 384       learning         26
# 492          power         23
# 158           data         16
# 573     scheduling         15
# 602          smart         14
# 173    development         14
# 313           home         13
# 361       internet         12
# 352    intelligent         11
# 300           grid         11
# 719       wearable         11
# 715          waste         11
# 215    electricity         10
# 643        systems         10
# 515       proposed          9
# 696           used          9
# 721           wind          9
# 364            iot          9
# 604           smes          9
# 471       parallel          9
# 428          model          9
# 174        devices          9
# 178        digital          8
# 653   technologies          8
# 654     technology          8
# 301    groundwater          7
# 675   transmission          7
# 545  reinforcement          7
# 214       electric          7
# 369            key          7
#
#
# Cluster 3:
#               word  frequency
# 522          power         32
# 640          solar         27
# 527     prediction         16
# 763           wind         16
# 637          smart         15
# 137    consumption         12
# 260             fl         12
# 387       learning         12
# 410     management         12
# 183      detection         11
# 672        systems         11
# 73       buildings         11
# 171         demand         11
# 679     techniques         11
# 159           data         10
# 227  environmental          9
# 727          urban          8
# 297           grid          8
# 55           based          8
# 203            dsm          7
# 27         anomaly          7
# 141        control          7
# 72        building          7
# 405        machine          7
# 264    forecasting          7
# 96          cities          7
# 316           hvac          7
# 90      challenges          7
# 226    environment          6
# 591        results          6
#
#
# Cluster 4:
#               word  frequency
# 263           data         43
# 956          smart         32
# 219    consumption         26
# 1100         water         26
# 285      detection         21
# 1010       systems         20
# 770          power         17
# 792     production         16
# 431      framework         15
# 929         sensor         15
# 612     management         15
# 457          green         14
# 959          solar         13
# 1019    technology         13
# 64    applications         13
# 726       pandemic         12
# 288    development         12
# 657         models         11
# 458           grid         11
# 522       industry         11
# 360    enterprises         10
# 123      buildings         10
# 330     efficiency          9
# 688            new          9
# 662     monitoring          9
# 589       lighting          9
# 802       proposed          9
# 416          fault          9
# 437         future          9
# 362    environment          8
#
#
# Cluster 5:
#               word  frequency
# 1195         smart         34
# 304           data         31
# 583           grid         24
# 397           edge         24
# 266    consumption         23
# 965          power         22
# 736       learning         21
# 330         design         20
# 712            iot         19
# 846        network         18
# 777     management         18
# 824          model         17
# 1204         solar         16
# 406       electric         15
# 277        control         15
# 531    forecasting         15
# 1145    scheduling         15
# 342        devices         15
# 1389       various         14
# 67        analysis         14
# 825         models         13
# 1423          wind         13
# 765        machine         13
# 1412         water         13
# 77    applications         13
# 540      framework         13
# 1012      proposed         13
# 997     production         12
# 1281       systems         12
# 320         demand         12
#
#
# Cluster 6:
#               word  frequency
# 733          smart         30
# 443            iot         21
# 127  communication         17
# 738          solar         16
# 614     production         16
# 603          power         15
# 156    consumption         14
# 856       wireless         12
# 356           grid         12
# 541         neural         12
# 184           data         12
# 774        systems         11
# 190           deep         11
# 106           city         11
# 490  manufacturing         11
# 355          green         10
# 634        quality         10
# 121  collaborative         10
# 832          using         10
# 241           edge          9
# 425   intelligence          9
# 516          model          9
# 778     technology          9
# 197         design          9
# 619       proposed          9
# 631             pv          8
# 318    forecasting          8
# 518         models          8
# 83        building          8
# 38    applications          8
#
#
# Cluster 7:
#              word  frequency
# 763         smart         33
# 194          data         28
# 616         power         19
# 447           iot         15
# 829       thermal         15
# 544       network         15
# 903         water         14
# 366          grid         14
# 887        values         13
# 227   development         12
# 771         solar         12
# 570  optimization         12
# 484          load         12
# 819       systems         12
# 532        models         11
# 769      software         11
# 471      learning         10
# 502    management         10
# 130       comfort         10
# 120        cities         10
# 188          crop          9
# 531         model          9
# 146     computing          9
# 561     occupants          8
# 390         human          8
# 48   applications          8
# 253       dynamic          7
# 750   significant          7
# 52   architecture          7
# 50       approach          7

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words='english')
corpus = data.loc[data['clusters']==]['processed_abstract']

def get_tfidf_top_features(documents,n_top=10):
      tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,  stop_words='english')
      tfidf = tfidf_vectorizer.fit_transform(documents)
      importance = np.argsort(np.asarray(tfidf.sum(axis=0)).ravel())[::-1]
      tfidf_feature_names = np.array(tfidf_vectorizer.get_feature_names())
      return tfidf_feature_names[importance[:n_top]]
    
get_tfidf_top_features(corpus)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [162], in <cell line: 14>()
#      11       tfidf_feature_names = np.array(tfidf_vectorizer.get_feature_names())
#      12       return tfidf_feature_names[importance[:n_top]]
# ---> 14 get_tfidf_top_features(corpus)
#
# Input In [162], in get_tfidf_top_features(documents, n_top)
#       7 def get_tfidf_top_features(documents,n_top=10):
#       8       tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,  stop_words='english')
# ----> 9       tfidf = tfidf_vectorizer.fit_transform(documents)
#      10       importance = np.argsort(np.asarray(tfidf.sum(axis=0)).ravel())[::-1]
#      11       tfidf_feature_names = np.array(tfidf_vectorizer.get_feature_names())
#
# File ~/opt/anaconda3/envs/Zeitreihenanalyseenv/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:2079, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    2072 self._check_params()
#    2073 self._tfidf = TfidfTransformer(
#    2074     norm=self.norm,
#    2075     use_idf=self.use_idf,
#    2076     smooth_idf=self.smooth_idf,
#    2077     sublinear_tf=self.sublinear_tf,
#    2078 )
# -> 2079 X = super().fit_transform(raw_documents)
#    2080 self._tfidf.fit(X)
#    2081 # X is already a transformed view of raw_documents so
#    2082 # we set copy to False
#
# File ~/opt/anaconda3/envs/Zeitreihenanalyseenv/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:1338, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1330             warnings.warn(
#    1331                 "Upper case characters found in"
#    1332                 " vocabulary while 'lowercase'"
#    1333                 " is True. These entries will not"
#    1334                 " be matched with any documents"
#    1335             )
#    1336             break
# -> 1338 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1340 if self.binary:
#    1341     X.data.fill(1)
#
# File ~/opt/anaconda3/envs/Zeitreihenanalyseenv/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:1228, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1226     vocabulary = dict(vocabulary)
#    1227     if not vocabulary:
# -> 1228         raise ValueError(
#    1229             "empty vocabulary; perhaps the documents only contain stop words"
#    1230         )
#    1232 if indptr[-1] > np.iinfo(np.int32).max:  # = 2**31 - 1
#    1233     if _IS_32BIT:
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words

# %%
data.loc[data['clusters']==1].head(30)
# Out:
#      Unnamed: 0                                              title  \
# 18           18  Intelligent analysis and design of heat pump b...
# 27           27  Renewable Energy Systems Energy Modeling using...
# 29           29  IoT based Framework for Smart Campus: COVID-19...
# 30           30  A Detailed Investigation on Potential Impact o...
# 44           44  TinyML Smart Sensor for Energy Saving in Inter...
# 59           59  Optimizing Computational Resources for Edge In...
# 70           70  Flexibility platform for community energy systems
# 74           74  Energy-efficient and Sustainable Construction ...
# 76           76  Digital revolution in efficient self-organizat...
# 88           88  Machine Learning Based Problem Solving Approac...
# 89           89  Prediction of Machine Learning Base for Effici...
# 91           91  The 5th Wave and i-Sustainability Plus Theorie...
# 110         110  Drones’ Edge Intelligence Over Smart Environme...
# 121         121  Smart Kitchen: Real Time Monitoring of Kitchen...
# 129         129  Power Quality Event Detection Using FAWT and B...
# 132         132  A gamified platform for energy feedback and us...
# 140         140  Intelligent energy consumption estimation for ...
# 144         144  Exploring Deep Learning and Tree-Based Ensembl...
# 146         146  Realization of Topology Matching Algorithm for...
# 162         162  Two Machine Learning Approaches for Short-Term...
# 178         178  Energy-Efficient and Secure IoT architecture b...
# 185         185       ThinkHome: A smart home as digital ecosystem
# 190         190  Design of IoT Gateway and DSM Implementation i...
# 199         199  Toward Intelligent Train Driving through Learn...
# 218         218  A Framework for Customer-Oriented IoT Product ...
# 238         238  Joint Scheduling Design in Wireless Powered ME...
# 243         243  Joint Computation Offloading and Resource Allo...
# 247         247  Green Vehicle Routing Problem: State of the Ar...
# 249         249  Solar Panel Identification Via Deep Semi-Super...
# 252         252  Electro: Toward QoS-Aware Power Management for...
#
#                                               abstract  \
# 18   Addressing concerns about security of energy s...
# 27   Communities using Sustainable Energy Systems (...
# 29   Internet of Things (IoT) plays an important ro...
# 30   Quantum computing is an emerging technology (Q...
# 44   Smart agriculture researchers bring numerous t...
# 59   As the number of interconnected devices increa...
# 70   Integrating technological changes and sustaina...
# 74   As a key part of sustainable urban development...
# 76   Artificial intelligence highlights in several ...
# 88   The issues related to conventional generation ...
# 89   The 21st century, which we live in today, is r...
# 91   The Covid-19 pandemic is changing our society ...
# 110  Edge Intelligence is an emerging technology wh...
# 121  As per the report of a media agency by Midshar...
# 129  Maintaining a smooth power supply is mandatory...
# 132  The current energy consumption behaviour of ma...
# 140  Nowadays, Fully Electric Vehicles are in the s...
# 144  During the past century, the energy consumptio...
# 146  With the development of the Internet and deliv...
# 162  The increasing liberalization of European elec...
# 178  Coronavirus is an extremely infectious and fat...
# 185  Smart homes have become increasingly popular i...
# 190  In the smart grid era, demand side management ...
# 199  As the most sustainable means of modern transp...
# 218  The Internet of Things (IoT) is a paradigm tha...
# 238  Internet of things (IoT) technology is critica...
# 243  With the rapid development of Artificial Intel...
# 247  Green vehicle routing problem (GVRP) aims to c...
# 249  As residential photovoltaic (PV) system instal...
# 252  Reducing the energy consumption of datacenters...
#
#                                     processed_abstract  clusters
# 18   addressing concerns climate drives shift green...         1
# 27   using grid locals data precise learning used p...         1
# 29   internet iot connecting everything together in...         1
# 30   quantum computing emerging technology qc quant...         1
# 44   agriculture bring prospects farm productivity ...         1
# 59   devices iot start flourish cost computational ...         1
# 70   integrating considerations poses multidiscipli...         1
# 74   key urban technologies materials key minimize ...         1
# 76   remarkable sublimate building sector push cons...         1
# 88   issues conventional generation arethe matter d...         1
# 89   century live changing fourth information commu...         1
# 91   pandemic society economic social businesses co...         1
# 110  edge intelligence intelligence edge drones dro...         1
# 121  smart kitchen kitchen room kitchen smart kitch...         1
# 129  power supply voltages voltage voltage voltages...         1
# 132  behaviour mankind causing results catastrophic...         1
# 140  nowadays fully vehicles spotlight mobility ove...         1
# 144  past century consumption planet drastically co...         1
# 146  development services exchange services popular...         1
# 162  proportion intermittent fed grids grids produc...         1
# 178  coronavirus extremely infectious fatal disease...         1
# 185  smart homes similarly planned guidelines homes...         1
# 190  demand management dsm contributes enduring adv...         1
# 199  modern modern railway driving railway enable d...         1
# 218  iot mimics smart human counterparts disruptive...         1
# 238  iot technology forthcoming iot technology char...         1
# 243  iot iot devices computing resources insufficie...         1
# 247  green vehicle routing gvrp routing vehicles fu...         1
# 249  residential pv installations continue utilitie...         1
# 252  consumption datacenters applications applicati...         1

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

df = pd.DataFrame(data)

# Initialize TF-IDF vectorizer
vectorizer = TfidfVectorizer(stop_words='english')

# Fit and transform the text data
X = vectorizer.fit_transform(df['processed_abstract'])

# Get feature names (words)
feature_names = vectorizer.get_feature_names_out()

# Create a DataFrame to hold TF-IDF values
tfidf_df = pd.DataFrame(X.toarray(), columns=feature_names)

# Add the 'clusters' column to the TF-IDF DataFrame
tfidf_df['clusters'] = df['clusters']

# Group by cluster
grouped = tfidf_df.groupby('clusters')

# Calculate the mean TF-IDF values for each cluster
cluster_tfidf_means = grouped.mean()

# Calculate the difference in TF-IDF means between the current cluster and other clusters
cluster_tfidf_diffs = cluster_tfidf_means.sub(cluster_tfidf_means.mean(axis=0), axis=1)

# Get the top words for each cluster based on the absolute differences in TF-IDF means
num_top_words = 10
top_words_per_cluster = {}
for cluster in cluster_tfidf_diffs.index:
    top_indices = cluster_tfidf_diffs.loc[cluster].abs().values.argsort()[-num_top_words:][::-1]
    top_words_per_cluster[cluster] = [feature_names[i] for i in top_indices]

# Print the top words for each cluster
for cluster, top_words in top_words_per_cluster.items():
    print(f"Cluster {cluster}:")
    print(top_words)
    print("\n")
# Out:
# Cluster -1:
# ['potentials', 'watchplant', 'fixing', 'mexico', 'soilless', 'environmentally', 'resourceful', 'usable', 'mfc', 'words']
#
#
# Cluster 0:
# ['potentials', 'soilless', 'nhs', 'thing', 'computers', 'factories', 'learners', 'tiny', 'consumes', 'digit']
#
#
# Cluster 1:
# ['dashboards', 'watchplant', 'small', 'grey', 'neutrality', 'potentials', 'technique', 'deduce', 'hifs', 'wildlife']
#
#
# Cluster 2:
# ['potentials', 'wastage', 'distribute', 'propose', 'ecuadorian', 'economy', 'gbr', 'biology', 'multiparametric', 'fixing']
#
#
# Cluster 3:
# ['producing', 'soilless', 'schedules', 'delm', 'manufacturers', 'small', 'watchplant', 'sensitizers', 'consumes', 'regulatory']
#
#
# Cluster 4:
# ['iomt', 'detecting', 'propose', 'managed', 'quantization', 'neumann', 'uses', 'counterparts', 'fixing', 'watchplant']
#
#
# Cluster 5:
# ['learners', 'small', 'consumes', 'neumann', 'watchplant', 'lln', 'dqn', 'forecast', 'pakistan', 'tilt']
#
#
# Cluster 6:
# ['technologies', 'logistic', 'watchplant', 'theoretically', 'user', 'kinds', 'dashboards', 'methodologies', 'schedules', 'vegetables']
#
#
# Cluster 7:
# ['learners', 'rescue', 'internationally', 'dashboards', 'potentials', 'technological', 'mass', 'predicting', 'propose', 'croatia']
