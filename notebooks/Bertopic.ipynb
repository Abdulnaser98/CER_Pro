# %%
# !pip install git+https://github.com/scikit-learn-contrib/hdbscan.git
! pip install bertopic
import os
import nltk
import datetime
import bertopic
import pandas as pd
from bertopic import BERTopic
from google.colab import drive
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA
nltk.download('vader_lexicon')
sia = SIA()
# Out:
# ...
#   Cloning https://github.com/scikit-learn-contrib/hdbscan.git to /tmp/pip-req-build-m564co9t
#   Running command git clone --filter=blob:none --quiet https://github.com/scikit-learn-contrib/hdbscan.git /tmp/pip-req-build-m564co9t
#   Resolved https://github.com/scikit-learn-contrib/hdbscan.git to commit e5e1b8e7a348fc06e99d71d35e72d0e51c066194
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for hdbscan: filename=hdbscan-0.8.33-cp310-cp310-linux_x86_64.whl size=3039007 sha256=fbeef390f4fce978ddfee1b5108d2d950300534ca0ab431001e25a7a90be496f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xq0csu9c/wheels/dd/9a/ab/564a6c3e58f76c492ab1104d636e794e2fe7b879ba02e344d2
# Successfully built hdbscan
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 11.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Import Data

# %%
papers = pd.read_csv('data_full_processed.csv')
papers['abstract']
# Out:
# 0      Artificial Intelligence (AI) has the potential...
# 1      Sustainability, to describe it in simpler word...
# 2      Sustainability is a vast subject involving var...
# 3      Artificial Intelligence (AI) is a rapidly adva...
# 4      In the recent era, for most sustainable smart ...
#                              ...
# 358    Integrated approaches across energy, water and...
# 359    The dynamic nature of sustainable energy and e...
# 360    In recent decade, the number of devices involv...
# 361    The evolution of artificial intelligence (AI) ...
# 362    Harvesting ocean wave energy is a killer appli...
# Name: abstract, Length: 363, dtype: object

# %% [markdown]
# # Topic modeling

# %%
model = BERTopic(verbose=True,embedding_model='paraphrase-MiniLM-L3-v2', min_topic_size= 5)
headline_topics, _ = model.fit_transform(papers['processed_abstract'])
# Out:
# Batches:   0%|          | 0/12 [00:00<?, ?it/s]
# 2023-07-27 11:37:49,470 - BERTopic - Transformed documents to Embeddings
# 2023-07-27 11:37:52,304 - BERTopic - Reduced dimensionality
# 2023-07-27 11:37:52,318 - BERTopic - Clustered reduced embeddings

# %%
freq = model.get_topic_info()
print("Number of topics: {}".format( len(freq)))
freq.head(40)
# Out:
# Number of topics: 17
#     Topic  Count                                         Name  \
# 0      -1    110             -1_data_edge_internet_scheduling
# 1       0     42               0_iot_devices_wireless_network
# 2       1     31                     1_grid_power_smart_grids
# 3       2     28                     2_smart_cities_city_home
# 4       3     24                      3_solar_power_pv_panels
# 5       4     21      4_models_prediction_control_forecasting
# 6       5     16                 5_water_crop_irrigation_data
# 7       6     13  6_manufacturing_production_enterprises_smes
# 8       7     13          7_wind_power_maintenance_prediction
# 9       8     13         8_green_finance_issues_communication
# 10      9     12            9_network_inference_neural_memory
# 11     10      9            10_thermal_comfort_buildings_hvac
# 12     11      7         11_learning_distributed_federated_dr
# 13     12      6        12_waste_biomass_bioenergy_management
# ...
